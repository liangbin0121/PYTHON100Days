# %% [markdown]
# # [作業目標]
#
# 1. [簡答題] 請問下列四種不同的 DataFrame 選取結果有什麼差異？
#
# ```
# df.loc[ '2013-01-01', 'A']
# df.loc[ '2013-01-01', ['A', 'B'] ]
# df.loc[ '2013-01-01':'2013-01-02', 'A' ]
# df.loc[ '2013-01-01':'2013-01-05', 'A':'C']
# ```
#
#
# 2. 請根據提供的資料，選擇出下列的要求：
#
# ```
# # - select the first 3 rows.
# # - select the odd rows. (index = 1, 3, 5)
# # - select the last 2 columns.
# # - select the even columns. (index = 0, 2, 4)
# ```
#
# 3. 請根據提供的資料，選擇出下列的要求：
#
# ```
# # - 1. filtered by first column > 20?
# # - 2. filtered by first column + second column > 50
# # - 3. filtered by first column < 30 or second column > 30
# # - 4. filtered by total sum of row > 100
# ```

# %%
# 連接個人資料 讀取 ＰＴＴ 訓練資料和儲存模型
#先連接自己的GOOGLE DRIVE 為了要儲存資料和訓練模型
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Current directory
print(os.getcwd())

# change directory
os.chdir('/content/drive/MyDrive/python_training/PYTHON100Days/D10-Pandas_DataFrame的資料選取/')
print(os.getcwd())
# Out:
# /content
# /content/drive/MyDrive/python_training/PYTHON100Days/D10-Pandas_DataFrame的資料選取

# %%
# 載入 NumPy, Pandas 套件
import numpy as np
import pandas as pd

# 檢查正確載入與版本
print(np)
print(np.__version__)
print(pd)
print(pd.__version__)
# Out:
# <module 'numpy' from '/usr/local/lib/python3.7/dist-packages/numpy/__init__.py'>
# 1.19.5
# <module 'pandas' from '/usr/local/lib/python3.7/dist-packages/pandas/__init__.py'>
# 1.1.5

# %% [markdown]
# # 作業

# %% [markdown]
# ### 1. [簡答題] 請問下列四種不同的 DataFrame 選取結果有什麼差異？
#
# ```
# df.loc[ '2013-01-01', 'A']
# df.loc[ '2013-01-01', ['A', 'B'] ]
# df.loc[ '2013-01-01':'2013-01-02', 'A' ]
# df.loc[ '2013-01-01':'2013-01-05', 'A':'C']
# ```

# %%
print("df.loc[ '2013-01-01', 'A'] 取得 2013-01-01 這列的 A 欄資料")
print("df.loc[ '2013-01-01', ['A', 'B'] ] ,取得 2013-01-01 這列的 A, B 二欄資料")
print("df.loc[ '2013-01-01':'2013-01-02', 'A' ] ，取得 2013-01-01 到 2013-01-02 這幾列的 A 欄資料")
print("df.loc[ '2013-01-01':'2013-01-05', 'A':'C'] ，取得 2013-01-01 到 2013-01-02 這幾列的 A 到 C 欄資料")
# Out:
# df.loc[ '2013-01-01', 'A'] 取得 2013-01-01 這列的 A 欄資料
# df.loc[ '2013-01-01', ['A', 'B'] ] ,取得 2013-01-01 這列的 A, B 二欄資料
# df.loc[ '2013-01-01':'2013-01-02', 'A' ] ，取得 2013-01-01 到 2013-01-02 這幾列的 A 欄資料
# df.loc[ '2013-01-01':'2013-01-05', 'A':'C'] ，取得 2013-01-01 到 2013-01-02 這幾列的 A 到 C 欄資料

# %% [markdown]
# ### 2. 請根據提供的資料，選擇出下列的要求：
#
# ```
# # - select the first 3 rows.
# # - select the odd rows. (index = 1, 3, 5)
# # - select the last 2 columns.
# # - select the even columns. (index = 0, 2, 4)
# ```

# %%
# 記得先 Import 正確的套件

'''
Your Code
'''
# Out:
# '\nYour Code\n'

# %%
df = pd.DataFrame(np.random.randn(6,3),columns=['col1','col2','col3'])
df
# Out:
#        col1      col2      col3
# 0 -0.970160 -0.633662  0.779174
# 1 -1.734710  0.798112  0.704500
# 2  0.649062 -1.038455 -0.414940
# 3  0.125899  1.659279  0.964368
# 4 -0.625608 -1.155195 -1.151168
# 5 -1.122055  0.680732 -1.171987

# %%
print(df.iloc[:,[0,2]])
# Out:
#        col1      col3
# 0 -0.970160  0.779174
# 1 -1.734710  0.704500
# 2  0.649062 -0.414940
# 3  0.125899  0.964368
# 4 -0.625608 -1.151168
# 5 -1.122055 -1.171987

# %%
# - select the first 3 rows.
print(df.iloc[0:3,:])
# Out:
#        col1      col2      col3
# 0 -0.970160 -0.633662  0.779174
# 1 -1.734710  0.798112  0.704500
# 2  0.649062 -1.038455 -0.414940

# %%
# - select the odd rows. (index = 1, 3, 5)
print(df.iloc[[1,3,5],:])
# Out:
#        col1      col2      col3
# 1 -1.734710  0.798112  0.704500
# 3  0.125899  1.659279  0.964368
# 5 -1.122055  0.680732 -1.171987

# %%
# - select the last 2 columns.
print(df.iloc[:,-2:])
# Out:
#        col2      col3
# 0 -0.633662  0.779174
# 1  0.798112  0.704500
# 2 -1.038455 -0.414940
# 3  1.659279  0.964368
# 4 -1.155195 -1.151168
# 5  0.680732 -1.171987

# %%
# - select the even columns. (index = 0, 2, 4)
print(df.iloc[:,[1]])
# Out:
#        col2
# 0 -0.633662
# 1  0.798112
# 2 -1.038455
# 3  1.659279
# 4 -1.155195
# 5  0.680732

# %% [markdown]
# ### 3. 請根據提供的資料，選擇出下列的要求：
#
# ```
# # - 1. filtered by first column > 20?
# # - 2. filtered by first column + second column > 50
# # - 3. filtered by first column < 30 or second column > 30
# # - 4. filtered by total sum of row > 100
# ```

# %%
df = pd.DataFrame(np.random.randint(10, 40, 60).reshape(-1, 4))
df
# Out:
#      0   1   2   3
# 0   26  26  16  27
# 1   27  37  23  21
# 2   21  39  16  12
# 3   19  38  32  28
# 4   10  27  35  37
# 5   38  19  28  13
# 6   37  37  18  30
# 7   31  28  11  28
# 8   26  25  17  24
# 9   28  16  10  21
# 10  10  35  34  19
# 11  16  24  12  14
# 12  11  27  38  25
# 13  33  14  39  36
# 14  14  11  29  25

# %%
# - 1. filtered by first column > 20?
print(df[df.iloc[:,0]>20])
# Out:
#      0   1   2   3
# 0   26  26  16  27
# 1   27  37  23  21
# 2   21  39  16  12
# 5   38  19  28  13
# 6   37  37  18  30
# 7   31  28  11  28
# 8   26  25  17  24
# 9   28  16  10  21
# 13  33  14  39  36

# %%
# - 2. filtered by first column + second column > 50
print(df[(df.iloc[:,0]+df.iloc[:,1])>50])
# Out:
#     0   1   2   3
# 0  26  26  16  27
# 1  27  37  23  21
# 2  21  39  16  12
# 3  19  38  32  28
# 5  38  19  28  13
# 6  37  37  18  30
# 7  31  28  11  28
# 8  26  25  17  24

# %%
# - 3. filtered by first column < 30 or second column > 30

print(df[(df[1]>30)|(df[0]<30)])
# Out:
#      0   1   2   3
# 0   26  26  16  27
# 1   27  37  23  21
# 2   21  39  16  12
# 3   19  38  32  28
# 4   10  27  35  37
# 6   37  37  18  30
# 8   26  25  17  24
# 9   28  16  10  21
# 10  10  35  34  19
# 11  16  24  12  14
# 12  11  27  38  25
# 14  14  11  29  25

# %%
# - 4. filtered by total sum of row > 100
print(df[df.sum(axis=1) > 100])
# Out:
#      0   1   2   3
# 1   27  37  23  21
# 3   19  38  32  28
# 4   10  27  35  37
# 6   37  37  18  30
# 12  11  27  38  25
# 13  33  14  39  36

# %%
print(df.iloc[0:13,:])
# Out:
#      0   1   2   3
# 0   26  26  16  27
# 1   27  37  23  21
# 2   21  39  16  12
# 3   19  38  32  28
# 4   10  27  35  37
# 5   38  19  28  13
# 6   37  37  18  30
# 7   31  28  11  28
# 8   26  25  17  24
# 9   28  16  10  21
# 10  10  35  34  19
# 11  16  24  12  14
# 12  11  27  38  25
