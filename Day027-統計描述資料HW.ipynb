# %% [markdown]
# ## 作業:
# 今天學到不同統計量之間特性，
# 試著分析男生女生身高資料，
# 試著回答下面的問題:
# Q1:試著用今天所教的內容，如何描述這兩組資料的樣態?
# Q2: 請問男生和女生在平均身高上誰比較高?
# Q3:請問第二題的答案和日常生活中觀察的一致嗎? 如果不一致，你覺得原因可能為何?
# 上述問題透過  python 語法進行運算，
# 並將上述答案填寫在 (google 表單)[https://docs.google.com/forms/d/e/1FAIpQLSdDzwpeJl8YLPwZaW8pBZvtuXY9kIbbZLqxcXyzFaoraV5JEA/viewform ]
#
# https://docs.google.com/forms/d/e/1FAIpQLSdDzwpeJl8YLPwZaW8pBZvtuXY9kIbbZLqxcXyzFaoraV5JEA/viewform
#
# ![](作業資料圖檔.PNG)

# %%
# library
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import math
import statistics
import seaborn as sns

# %%
## 輸入資料
boys=[164, 176, 169, 169, 165, 175, 159, 151, 144, 160, 183, 165, 156, 170,
      164, 173, 165, 163, 177, 171]
girls=[169, 183, 170, 168, 182, 170, 173, 185, 151, 156, 162, 169, 162, 181,
       159, 154, 167, 175, 170, 160]

childen=pd.DataFrame([boys,girls]).T
childen.columns = ['boys', 'girls']
childen
# Out:
#     boys  girls
# 0    164    169
# 1    176    183
# 2    169    170
# 3    169    168
# 4    165    182
# 5    175    170
# 6    159    173
# 7    151    185
# 8    144    151
# 9    160    156
# 10   183    162
# 11   165    169
# 12   156    162
# 13   170    181
# 14   164    159
# 15   173    154
# 16   165    167
# 17   163    175
# 18   177    170
# 19   171    160

# %%
#Q1:試著用今天所教的內容，如何描述這兩組資料的樣態?
#暗示:  分別計算男生和女生的統計量
childen.describe()
# Out:
#              boys       girls
# count   20.000000   20.000000
# mean   165.950000  168.300000
# std      9.213691    9.766215
# min    144.000000  151.000000
# 25%    162.250000  161.500000
# 50%    165.000000  169.000000
# 75%    171.500000  173.500000
# max    183.000000  185.000000

# %%
childen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   boys    20 non-null     int64
#  1   girls   20 non-null     int64
# dtypes: int64(2)
# memory usage: 448.0 bytes

# %%
# 計算統計量_平均數的方法
mean_boy=np.mean(boys)
print("男孩身高平均=",mean_boy)

statistics_mean_boy=statistics.mean(boys)
print("statistics_mean_boy=",statistics_mean_boy)
# 計算統計量_平均數的方法
mean_girl=np.mean(girls)
print("女孩身高平均=",mean_girl)

statistics_mean_girl=statistics.mean(girls)
print("statistics_mean_girl=",statistics_mean_girl)
# Out:
# 男孩身高平均= 165.95
# statistics_mean_boy= 165.95
# 女孩身高平均= 168.3
# statistics_mean_girl= 168.3

# %%
# 計算統計量_中位數的方法
np_median_boy=np.median(boys,axis=None)
print("np_median_boy=",np_median_boy)
statistics_median_boy=statistics.median(boys)
print("statistics_median_boy=",statistics_median_boy)

np_median_girl=np.median(girls,axis=None)
print("np_median_girl=",np_median_girl)
statistics_median_girl=statistics.median(girls)
print("statistics_median_girl=",statistics_median_girl)
# Out:
# np_median_boy= 165.0
# statistics_median_boy= 165.0
# np_median_girl= 169.0
# statistics_median_girl= 169.0

# %%
#計算統計量_眾數
mode_boy=stats.mode(boys,axis=None)
print("男孩身高眾數=",mode_boy[0][0])

mode_girl=stats.mode(girls,axis=None)
print("女孩身高眾數=",mode_girl[0][0])
childen.mode()
# Out:
# 男孩身高眾數= 165
# 女孩身高眾數= 170
#    boys  girls
# 0   165    170

# %%
##計算全距:
def rangeV(x): 
  return(max(x)-min(x))
    
print("男孩身高全距=",rangeV(boys))
print("女孩身高全距=",rangeV(girls))
# Out:
# 男孩身高全距= 39
# 女孩身高全距= 34

# %%
#計算變異數
print("男孩身高變異數=",np.var(boys,ddof=1))
print("男孩身高變異數=",np.var(girls,ddof=1))
childen.var()
# Out:
# 男孩身高變異數= 84.89210526315789
# 男孩身高變異數= 95.37894736842104
# boys     84.892105
# girls    95.378947
# dtype: float64

# %%
#計算標準差
std_boy=np.std(boys,ddof=1)
print("男孩身高標準差=",std_boy)
std_girl=np.std(girls,ddof=1)
print("女孩身高標準差=",std_girl)
childen.std()
# Out:
# 男孩身高標準差= 9.213691185575838
# 女孩身高標準差= 9.766214587465353
# boys     9.213691
# girls    9.766215
# dtype: float64

# %%
## python 百分位數
#np
print("男孩身高90百分位數=",np.percentile(boys, 90))
print("男孩身高50百分位數=",np.percentile(boys, 50))
print("男孩身高20百分位數=",np.percentile(boys, 20))

print("女孩身高90百分位數=",np.percentile(girls, 90))
print("女孩身高50百分位數=",np.percentile(girls, 50))
print("女孩身高20百分位數=",np.percentile(girls, 20))
# Out:
# 男孩身高90百分位數= 176.1
# 男孩身高50百分位數= 165.0
# 男孩身高20百分位數= 159.8
# 女孩身高90百分位數= 182.1
# 女孩身高50百分位數= 169.0
# 女孩身高20百分位數= 159.8

# %%
# 計算偏度
print("男孩身高偏度:",stats.skew(boys))
print("女孩身高偏度:",stats.skew(girls))
childen.skew()
# Out:
# 男孩身高偏度: -0.47132127317376954
# 女孩身高偏度: 0.05985321129365068
# boys    -0.51043
# girls    0.06482
# dtype: float64

# %%
# 計算峰度
print("男孩身高峰度:",stats.kurtosis(boys)) ##與(normal分布-3)的差距
print("女孩身高峰度:",stats.kurtosis(girls)) ##與(normal分布-3)的差距
childen.kurtosis()
# Out:
# 男孩身高峰度: 0.19395882957876331
# 女孩身高峰度: -0.8203607083948947
# boys     0.625456
# girls   -0.697137
# dtype: float64

# %%
#最後，畫圖看分布
## alpha透明度，bins長條數量
plt.hist(boys,alpha=.4,bins=40)
plt.title('boy,skewness={0},kurtosis={1}'.format(round(stats.skew(boys),2),round(stats.kurtosis(boys),2)))
plt.axvline(x=mean_boy)
plt.show()

# %%
#最後，畫圖看分布
## alpha透明度，bins長條數量
plt.hist(girls,alpha=.4,bins=40)
plt.title('girl,skewness={0},kurtosis={1}'.format(round(stats.skew(girls),2),round(stats.kurtosis(girls),2)))
plt.axvline(x=mean_girl)
plt.show()

# %%
plt.hist(boys,alpha=.4)
plt.hist(girls,color=sns.desaturate("indianred",0.8),alpha=0.4)
plt.title("all samples")
plt.axvline(x=mean_girl,color=sns.desaturate("indianred",0.8))
plt.axvline(x=mean_boy)
plt.show()

# %% [markdown]
# 從分布看來，女生的平均身高較高，且資料較為集中。男生的資料較為分散

# %%
###Q2: 請問男生和女生在平均身高上誰比較高?

whotall=childen.mean().idxmax()
print("%s平均而言比較高" %whotall)

mean_boy=np.mean(boys)
print("男生身高平均:",mean_boy)
mean_girl=np.mean(girls)
print("女生身高平均:",mean_girl)

# print("女生平均而言比較高")
# Out:
# girls平均而言比較高
# 男生身高平均: 165.95
# 女生身高平均: 168.3

# %%
#Q3:請問第二題的答案和日常生活中觀察的一致嗎? 如果不一致，你覺得原因可能為何? 
'''
和日常的觀察不一致，
樣本數量太少。
有可能是抽樣上有誤差，此樣本和母體的特性差異比較大。
'''
# Out:
# '\n和日常的觀察不一致，\n樣本數量太少。\n有可能是抽樣上有誤差，此樣本和母體的特性差異比較大。\n'
